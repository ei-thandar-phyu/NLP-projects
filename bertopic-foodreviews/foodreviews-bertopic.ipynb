# %% [markdown]
# # Topic Modeling with BERTopic for Amazon Fine Food Reviews

# %% [markdown]
# In this project, we will explore "Amazon Fine Food Reviews" dataset that consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012.
#
# We will find topics specifically in negative feedback (e.g., 1-star and 2-star reviews) to uncover recurring problems, complaints, or dissatisfaction themes.

# %% [markdown]
# ## Data Preparation
#
# * Dataset: https://www.kaggle.com/snap/amazon-fine-food-reviews

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
df = pd.read_csv('/kaggle/input/amazon-fine-food-reviews/Reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
#Filter the Dataset
negative_df = df[df['Score'].isin([1, 2])].copy()
negative_df.head()
# Out:
#     Id   ProductId          UserId     ProfileName  HelpfulnessNumerator  \
# 1    2  B00813GRG4  A1D87F6ZCVE5NK          dll pa                     0
# 3    4  B000UA0QIQ  A395BORC6FGVXV            Karl                     3
# 12  13  B0009XLVG0   A327PCT23YH90              LT                     1
# 16  17  B001GVISJM  A3KLWF6WQ5BNYO  Erica Neathery                     0
# 26  27  B001GVISJM  A3RXAU2N8KV45G          lady21                     0
#
#     HelpfulnessDenominator  Score        Time  \
# 1                        0      1  1346976000
# 3                        3      2  1307923200
# 12                       1      1  1339545600
# 16                       0      2  1348099200
# 26                       1      1  1332633600
#
#                                  Summary  \
# 1                      Not as Advertised
# 3                         Cough Medicine
# 12  My Cats Are Not Fans of the New Food
# 16                            poor taste
# 26                       Nasty No flavor
#
#                                                  Text
# 1   Product arrived labeled as Jumbo Salted Peanut...
# 3   If you are looking for the secret ingredient i...
# 12  My cats have been happily eating Felidae Plati...
# 16  I love eating them and they are good for watch...
# 26  The candy is just red , No flavor . Just  plan...

# %%
negative_df.shape
# Out:
# (82037, 10)

# %% [markdown]
# ## Data Preprocessing

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary resources
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # Convert to lowercase
    text = str(text).lower()

    # Remove URLs
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)
    
    # Remove @mentions and hashtags
    text = re.sub(r'\@\w+|\#','', text)
    
    # Remove numbers and punctuation
    text = re.sub(r"[^a-z\s]", '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # Tokenize, remove stopwords, and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words]
    
    return ' '.join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

negative_df['Clean_Text'] = negative_df['Text'].progress_apply(clean_text)
negative_df.head()
# Out:
#   0%|          | 0/82037 [00:00<?, ?it/s]
#     Id   ProductId          UserId     ProfileName  HelpfulnessNumerator  \
# 1    2  B00813GRG4  A1D87F6ZCVE5NK          dll pa                     0
# 3    4  B000UA0QIQ  A395BORC6FGVXV            Karl                     3
# 12  13  B0009XLVG0   A327PCT23YH90              LT                     1
# 16  17  B001GVISJM  A3KLWF6WQ5BNYO  Erica Neathery                     0
# 26  27  B001GVISJM  A3RXAU2N8KV45G          lady21                     0
#
#     HelpfulnessDenominator  Score        Time  \
# 1                        0      1  1346976000
# 3                        3      2  1307923200
# 12                       1      1  1339545600
# 16                       0      2  1348099200
# 26                       1      1  1332633600
#
#                                  Summary  \
# 1                      Not as Advertised
# 3                         Cough Medicine
# 12  My Cats Are Not Fans of the New Food
# 16                            poor taste
# 26                       Nasty No flavor
#
#                                                  Text  \
# 1   Product arrived labeled as Jumbo Salted Peanut...
# 3   If you are looking for the secret ingredient i...
# 12  My cats have been happily eating Felidae Plati...
# 16  I love eating them and they are good for watch...
# 26  The candy is just red , No flavor . Just  plan...
#
#                                            Clean_Text
# 1   product arrived labeled jumbo salted peanutsth...
# 3   looking secret ingredient robitussin believe f...
# 12  cat happily eating felidae platinum two year g...
# 16  love eating good watching tv looking movie swe...
# 26        candy red flavor plan chewy would never buy

# %% [markdown]
# ## Training the model
#
# Ref: https://maartengr.github.io/BERTopic/getting_started/best_practices/best_practices.html

# %%
# %%capture
# !pip install bertopic

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer

# Get embeddings
reviews = negative_df['Clean_Text'].tolist()
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(reviews, show_progress_bar=True)

# Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, metric='cosine', random_state=42)

# Cluster the reduced embedding
hdbscan_model = HDBSCAN(min_cluster_size=150, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Vectorizer and c-TFIDF
vectorizer_model = CountVectorizer(min_df=2, ngram_range=(1, 2))
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Dictionary to hold models and results
topic_models = {}

# Initialize and train model
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    verbose=True
)

topics, probs = topic_model.fit_transform(reviews, embeddings)

# Show topics
topic_model.get_topic_info()
# Out:
# 2025-05-04 16:54:14.813839: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746377654.836336     569 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746377654.842596     569 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Batches:   0%|          | 0/2564 [00:00<?, ?it/s]
# 2025-05-04 16:55:26,638 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-04 16:57:57,498 - BERTopic - Dimensionality - Completed ✓
# 2025-05-04 16:57:57,503 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-04 16:58:12,420 - BERTopic - Cluster - Completed ✓
# 2025-05-04 16:58:12,442 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-04 16:58:19,507 - BERTopic - Representation - Completed ✓
#     Topic  Count                                              Name  \
# 0      -1  34883                        -1_box_chip_amazon_product
# 1       0   9717                            0_coffee_cup_kcups_pod
# 2       1   5357                          1_dog_treat_dog food_toy
# 3       2   2870                     2_tea_green tea_green_tea bag
# 4       3   2277                        3_cat_litter_cat food_food
# 5       4   1805                         4_energy_juice_drink_soda
# 6       5   1704                   5_bread_gluten_cake_gluten free
# 7       6   1231                          6_oz_price_ounce_walmart
# 8       7   1218                 7_stevia_sugar_fructose_sweetener
# 9       8   1188                       8_china_made china_made_usa
# 10      9   1040               9_chocolate_cocoa_hot chocolate_hot
# 11     10   1037             10_peanut_butter_peanut butter_almond
# 12     11    985                         11_plant_seed_tree_flower
# 13     12    896                      12_popcorn_kernel_pop_popped
# 14     13    863        13_date_expiration_expiration date_expired
# 15     14    829                    14_taste_bad_tasted_taste like
# 16     15    824                15_jerky_beef jerky_beef_jack link
# 17     16    782                      16_cereal_oat_oatmeal_quaker
# 18     17    771                     17_sauce_curry_hot sauce_taco
# 19     18    742                  18_candy_gift_basket_gift basket
# 20     19    684                   19_baby_son_month old_baby food
# 21     20    642                           20_salt_sodium_salty_mg
# 22     21    633               21_coconut water_coconut_water_zico
# 23     22    629                             22_trap_moth_fly_mole
# 24     23    589                      23_email_order_item_received
# 25     24    526                      24_soup_miso_broth_miso soup
# 26     25    518                     25_leaking_leaked_seal_broken
# 27     26    506                   26_noodle_pasta_spaghetti_ramen
# 28     27    487                 27_hair_shampoo_scalp_conditioner
# 29     28    444                       28_gum_xylitol_spry_chewing
# 30     29    402                    29_olive_oil_truffle_olive oil
# 31     30    389               30_dented_can_can dented_dented can
# 32     31    384         31_ginger_lemon_ginger flavor_ginger snap
# 33     32    382            32_bar_protein bar_granola bar_granola
# 34     33    348                     33_tuna_sardine_salmon_smoked
# 35     34    318                   34_formula_arsenic_baby_similac
# 36     35    302                    35_cookie_cooky_ahoy_chip ahoy
# 37     36    294        36_cracker_love cracker_box cracker_graham
# 38     37    278                    37_cheese_mac_mac cheese_kraft
# 39     38    270                      38_chai_chai tea_clove_spice
# 40     39    255                    39_chip_kettle_kettle chip_bag
# 41     40    235                  40_chip_kale_kale chip_guacamole
# 42     41    233                     41_steam_steamer_beaba_brezza
# 43     42    205  42_msg_glutamate_monosodium_monosodium glutamate
# 44     43    201           43_whatever_science diet_eating_percent
# 45     44    191            44_milk_soy milk_almond milk_goat milk
# 46     45    189      45_chocolate_melted_ordered chocolate_godiva
# 47     46    181       46_bacon_like bacon_bacon flavor_love bacon
# 48     47    152  47_licorice_black licorice_licorice flavor_black
# 49     48    151       48_pretzel_burnt_burnt tastebr_pretzel good
#
#                                        Representation  \
# 0   [box, chip, amazon, product, bar, taste, flavo...
# 1   [coffee, cup, kcups, pod, roast, starbucks, kc...
# 2   [dog, treat, dog food, toy, bone, chew, puppy,...
# 3   [tea, green tea, green, tea bag, leaf, jasmine...
# 4   [cat, litter, cat food, food, eat, food cat, t...
# 5   [energy, juice, drink, soda, energy drink, caf...
# 6   [bread, gluten, cake, gluten free, flour, mix,...
# 7   [oz, price, ounce, walmart, store, shipping, d...
# 8   [stevia, sugar, fructose, sweetener, agave, sp...
# 9   [china, made china, made, usa, chicken jerky, ...
# 10  [chocolate, cocoa, hot chocolate, hot, dark ch...
# 11  [peanut, butter, peanut butter, almond, nut, a...
# 12  [plant, seed, tree, flower, bonsai, grow, soil...
# 13  [popcorn, kernel, pop, popped, popper, popping...
# 14  [date, expiration, expiration date, expired, s...
# 15  [taste, bad, tasted, taste like, batch, bitter...
# 16  [jerky, beef jerky, beef, jack link, turkey je...
# 17  [cereal, oat, oatmeal, quaker, raisin, flake, ...
# 18  [sauce, curry, hot sauce, taco, hot, spicy, ch...
# 19  [candy, gift, basket, gift basket, christmas, ...
# 20  [baby, son, month old, baby food, earth best, ...
# 21  [salt, sodium, salty, mg, sea salt, sea, much ...
# 22  [coconut water, coconut, water, zico, coco, vi...
# 23  [trap, moth, fly, mole, caught, squirrel, flea...
# 24  [email, order, item, received, th, never recei...
# 25  [soup, miso, broth, miso soup, campbell, soup ...
# 26  [leaking, leaked, seal, broken, box, arrived, ...
# 27  [noodle, pasta, spaghetti, ramen, texture, sau...
# 28  [hair, shampoo, scalp, conditioner, skin, wash...
# 29  [gum, xylitol, spry, chewing, trident, gum tas...
# 30  [olive, oil, truffle, olive oil, truffle oil, ...
# 31  [dented, can, can dented, dented can, dent, da...
# 32  [ginger, lemon, ginger flavor, ginger snap, gi...
# 33  [bar, protein bar, granola bar, granola, snack...
# 34  [tuna, sardine, salmon, smoked, fish, albacore...
# 35  [formula, arsenic, baby, similac, infant, eart...
# 36  [cookie, cooky, ahoy, chip ahoy, gooey, fudge,...
# 37  [cracker, love cracker, box cracker, graham, c...
# 38  [cheese, mac, mac cheese, kraft, macaroni, ann...
# 39  [chai, chai tea, clove, spice, tazo, tea, cinn...
# 40  [chip, kettle, kettle chip, bag, bag chip, hol...
# 41  [chip, kale, kale chip, guacamole, tortilla, t...
# 42  [steam, steamer, beaba, brezza, blade, baby, s...
# 43  [msg, glutamate, monosodium, monosodium glutam...
# 44  [whatever, science diet, eating, percent, scie...
# 45  [milk, soy milk, almond milk, goat milk, horiz...
# 46  [chocolate, melted, ordered chocolate, godiva,...
# 47  [bacon, like bacon, bacon flavor, love bacon, ...
# 48  [licorice, black licorice, licorice flavor, bl...
# 49  [pretzel, burnt, burnt tastebr, pretzel good, ...
#
#                                   Representative_Docs
# 0   [roller ball treat basically gravy roll around...
# 1   [probably good organic coffee whole bean form ...
# 2   [bought dog food bag showed pictured veggie ch...
# 3   [dont much care stash premium loose green tea ...
# 4   [bought cat food wonderful low price enjoy cat...
# 5   [love soda stream mix ive used quite good pret...
# 6   [mom celiac disease one son tree nut allergy a...
# 7   [oct ordered different vendor product oz pack ...
# 8   [yes know know agave nectar supposed answer se...
# 9   [br fda issue health warning veterinarian pet ...
# 10  [tried find ingredient hot cocoa bought couldn...
# 11  [flavor overwhelming peanut ie peanut butter f...
# 12  [bought christmas present thinking would cool ...
# 13  [ordered deluxe oz red popcorn maker machine p...
# 14  [cant give negative amount starsbr br love coo...
# 15  [im picky eater far worst tasting thing every ...
# 16  [let say first family keep high protein low ca...
# 17  [love oatmeal usually eat archer farm organic ...
# 18  [im fan spice almost problem put hot sauce and...
# 19  [ordered gift boyfriend family december meetin...
# 20  [pretty avid whole food shopper felt pretty go...
# 21  [used quality salt year always especially love...
# 22  [updateaccording article cnncom nutritional co...
# 23  [cat dog flea infestation bad got bitten sleep...
# 24  [extremely dissatisfied product customer servi...
# 25  [saw advertisement new line soup really intere...
# 26  [chili sauce wonderful fresh chili taste serve...
# 27  [always looking healthier whole grain version ...
# 28  [ok historically liked dove product body wash ...
# 29  [dentist recommended spry thought id give chan...
# 30  [im flabbergasted glowing review truffle oil r...
# 31  [first started ordering product amazon receive...
# 32  [spicy thai chip used best tasting chip market...
# 33  [bought couple box creamy peanut butter amazon...
# 34  [read label buy flavor bff list following two ...
# 35  [hellobr br felt important share review fellow...
# 36  [chip ahoy chewy gooey megafudge buqubr br rec...
# 37  [love cracker price changebr br box box sign s...
# 38  [buy quality natural mac cheese quite regularl...
# 39  [wow looking forward great review got today ma...
# 40  [loved chip chip would buy discovered england ...
# 41  [sale wouldnt bought tried brand guacamole fla...
# 42  [beaba blog giveaway dont think would ever spe...
# 43  [havent even tried stuff yet first ingredient ...
# 44  [review make sound really stupid whatever dont...
# 45  [kid drinking milk year lunch loved bought pac...
# 46  [living new york city people know jacques torr...
# 47  [heard salt forum back many people said real t...
# 48  [ordered licorice another seller several time ...
# 49  [excited high protein pretzel opened tasted ta...

# %% [markdown]
# ## Visualize Topics

# %%
topic_model.visualize_barchart(top_n_topics=16)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8b985d0-d5d7-4db3-a165-4fa40c35e98c" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8b985d0-d5d7-4db3-a165-4fa40c35e98c")) {                    Plotly.newPlot(                        "f8b985d0-d5d7-4db3-a165-4fa40c35e98c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.2160466721489919,0.22196782678669902,0.22249013770430487,0.2382136148296567,0.31902365100288743],"y":["roast  ","pod  ","kcups  ","cup  ","coffee  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.22162442277794261,0.22272746395441928,0.22357212442696656,0.23684333169887137,0.31566474401445194],"y":["bone  ","toy  ","dog food  ","treat  ","dog  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.2352804505535101,0.24752372355306748,0.2670820769048698,0.3082123485256532,0.4358793799580712],"y":["leaf  ","tea bag  ","green  ","green tea  ","tea  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.2108534674181825,0.23219095226281655,0.2606055680637454,0.27189873651468693,0.4236179862564159],"y":["eat  ","food  ","cat food  ","litter  ","cat  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.22899192988039,0.2413530638496836,0.287893133504661,0.3082799360844186,0.31024153436850455],"y":["energy drink  ","soda  ","drink  ","juice  ","energy  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.3278213216160239,0.3445526576014687,0.3489252428752919,0.36991973309725595,0.3704611697617446],"y":["flour  ","gluten free  ","cake  ","gluten  ","bread  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.24093514086106213,0.24286594185800586,0.3030364217891211,0.3488718246253664,0.39267592160953263],"y":["store  ","walmart  ","ounce  ","price  ","oz  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.27763087500621464,0.2859037030475829,0.3134580068961902,0.3197811249971729,0.3525624831480158],"y":["agave  ","sweetener  ","fructose  ","sugar  ","stevia  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.33527377299981137,0.35115152439796143,0.35644007896425955,0.5007335907398701,0.5716844332975927],"y":["chicken jerky  ","usa  ","made  ","made china  ","china  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.3030653631398925,0.3207766485659092,0.37204309548071457,0.4063697197190554,0.45938661812080545],"y":["dark chocolate  ","hot  ","hot chocolate  ","cocoa  ","chocolate  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.3682358422675957,0.37052747937415703,0.4482451400968028,0.4577935154065253,0.5380094971137215],"y":["nut  ","almond  ","peanut butter  ","butter  ","peanut  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.3422517402119603,0.38004263417160494,0.4007272969839886,0.46131554428599847,0.49823453516239075],"y":["bonsai  ","flower  ","tree  ","seed  ","plant  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.36096436037607166,0.3777347756073867,0.39194621197721463,0.427802347665578,0.7227809712614253],"y":["popper  ","popped  ","pop  ","kernel  ","popcorn  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.28927050787807745,0.3429840704784839,0.4598319331967729,0.47354681421506734,0.5101630012730402],"y":["sta ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d2e591a8-5f26-4c40-b065-30955e68361d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2e591a8-5f26-4c40-b065-30955e68361d")) {                    Plotly.newPlot(                        "d2e591a8-5f26-4c40-b065-30955e68361d",                        [{"customdata":[[0,"coffee | cup | kcups | pod | roast",9717],[1,"dog | treat | dog food | toy | bone",5357],[2,"tea | green tea | green | tea bag | leaf",2870],[3,"cat | litter | cat food | food | eat",2277],[4,"energy | juice | drink | soda | energy drink",1805],[5,"bread | gluten | cake | gluten free | flour",1704],[6,"oz | price | ounce | walmart | store",1231],[7,"stevia | sugar | fructose | sweetener | agave",1218],[8,"china | made china | made | usa | chicken jerky",1188],[9,"chocolate | cocoa | hot chocolate | hot | dark chocolate",1040],[10,"peanut | butter | peanut butter | almond | nut",1037],[11,"plant | seed | tree | flower | bonsai",985],[12,"popcorn | kernel | pop | popped | popper",896],[13,"date | expiration | expiration date | expired | stale",863],[14,"taste | bad | tasted | taste like | batch",829],[15,"jerky | beef jerky | beef | jack link | turkey jerky",824],[16,"cereal | oat | oatmeal | quaker | raisin",782],[17,"sauce | curry | hot sauce | taco | hot",771],[18,"candy | gift | basket | gift basket | christmas",742],[19,"baby | son | month old | baby food | earth best",684],[20,"salt | sodium | salty | mg | sea salt",642],[21,"coconut water | coconut | water | zico | coco",633],[22,"trap | moth | fly | mole | caught",629],[23,"email | order | item | received | th",589],[24,"soup | miso | broth | miso soup | campbell",526],[25,"leaking | leaked | seal | broken | box",518],[26,"noodle | pasta | spaghetti | ramen | texture",506],[27,"hair | shampoo | scalp | conditioner | skin",487],[28,"gum | xylitol | spry | chewing | trident",444],[29,"olive | oil | truffle | olive oil | truffle oil",402],[30,"dented | can | can dented | dented can | dent",389],[31,"ginger | lemon | ginger flavor | ginger snap | ginger lemon",384],[32,"bar | protein bar | granola bar | granola | snack bar",382],[33,"tuna | sardine | salmon | smoked | fish",348],[34,"formula | arsenic | baby | similac | infant",318],[35,"cookie | cooky | ahoy | chip ahoy | gooey",302],[36,"cracker | love cracker | box cracker | graham | cracker broken",294],[37,"cheese | mac | mac cheese | kraft | macaroni",278],[38,"chai | chai tea | clove | spice | tazo",270],[39,"chip | kettle | kettle chip | bag | bag chip",255],[40,"chip | kale | kale chip | guacamole | tortilla",235],[41,"steam | steamer | beaba | brezza | blade",233],[42,"msg | glutamate | monosodium | monosodium glutamate | glutamic",205],[43,"whatever | science diet | eating | percent | science",201],[44,"milk | soy milk | almond milk | goat milk | horizon",191],[45,"chocolate | melted | ordered chocolate | godiva | truffle",189],[46,"bacon | like bacon | bacon flavor | love bacon | bacon salt",181],[47,"licorice | black licorice | licorice flavor | black | licorice taste",152],[48,"pretzel | burnt | burnt tastebr | pretzel good | pretzel ive",151]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[9717,5357,2870,2277,1805,1704,1231,1218,1188,1040,1037,985,896,863,829,824,782,771,742,684,642,633,629,589,526,518,506,487,444,402,389,384,382,348,318,302,294,278,270,255,235,233,205,201,191,189,181,152,151],"sizemode":"area","sizeref":6.073125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[13.613191,-0.66004175,13.51532,-0.453 ...

# %%
# Get the top words in Topic 0
top_words_topic_0 = topic_model.get_topic(0)
print("Top words in Topic 5:", top_words_topic_0)

# Get the top words in Topic 2
top_words_topic_2 = topic_model.get_topic(2)
print("Top words in Topic 2:", top_words_topic_2)

# Get the top words in Topic 38
top_words_topic_38 = topic_model.get_topic(38)
print("Top words in Topic 38:", top_words_topic_38)
# Out:
# Top words in Topic 5: [('coffee', 0.31902365100288743), ('cup', 0.2382136148296567), ('kcups', 0.22249013770430487), ('pod', 0.22196782678669902), ('roast', 0.2160466721489919), ('starbucks', 0.20161280096473155), ('kcup', 0.19988676177014714), ('keurig', 0.19673825246435842), ('weak', 0.1831696613265393), ('bean', 0.1786750594192751)]
# Top words in Topic 2: [('tea', 0.4358793799580712), ('green tea', 0.3082123485256532), ('green', 0.2670820769048698), ('tea bag', 0.24752372355306748), ('leaf', 0.2352804505535101), ('jasmine', 0.21967011370646877), ('black tea', 0.19652412867467503), ('tea taste', 0.19140035078228346), ('matcha', 0.1827805383324629), ('earl', 0.18037728753099738)]
# Top words in Topic 38: [('chai', 0.7765776770997975), ('chai tea', 0.5522085960813354), ('clove', 0.41886581863865663), ('spice', 0.3792129494847659), ('tazo', 0.3529988685550384), ('tea', 0.3487895935454036), ('cinnamon', 0.3282669280666814), ('love chai', 0.32664186784333543), ('latte', 0.2996226733751508), ('black tea', 0.28515083536203334)]

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8531bb05-5a45-44ed-8b2b-00355a72cda8" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8531bb05-5a45-44ed-8b2b-00355a72cda8")) {                    Plotly.newPlot(                        "8531bb05-5a45-44ed-8b2b-00355a72cda8",                        [{"coloraxis":"coloraxis","name":"0","x":["0_coffee_cup_kcups","1_dog_treat_dog food","2_tea_green tea_green","3_cat_litter_cat food","4_energy_juice_drink","5_bread_gluten_cake","6_oz_price_ounce","7_stevia_sugar_fructose","8_china_made china_made","9_chocolate_cocoa_hot choco...","10_peanut_butter_peanut but...","11_plant_seed_tree","12_popcorn_kernel_pop","13_date_expiration_expirati...","14_taste_bad_tasted","15_jerky_beef jerky_beef","16_cereal_oat_oatmeal","17_sauce_curry_hot sauce","18_candy_gift_basket","19_baby_son_month old","20_salt_sodium_salty","21_coconut water_coconut_wa...","22_trap_moth_fly","23_email_order_item","24_soup_miso_broth","25_leaking_leaked_seal","26_noodle_pasta_spaghetti","27_hair_shampoo_scalp","28_gum_xylitol_spry","29_olive_oil_truffle","30_dented_can_can dented","31_ginger_lemon_ginger flavor","32_bar_protein bar_granola ...","33_tuna_sardine_salmon","34_formula_arsenic_baby","35_cookie_cooky_ahoy","36_cracker_love cracker_box...","37_cheese_mac_mac cheese","38_chai_chai tea_clove","39_chip_kettle_kettle chip","40_chip_kale_kale chip","41_steam_steamer_beaba","42_msg_glutamate_monosodium","43_whatever_science diet_ea...","44_milk_soy milk_almond milk","45_chocolate_melted_ordered...","46_bacon_like bacon_bacon f...","47_licorice_black licorice_...","48_pretzel_burnt_burnt tast..."],"y":["0_coffee_cup_kcups","1_dog_treat_dog food","2_tea_green tea_green","3_cat_litter_cat food","4_energy_juice_drink","5_bread_gluten_cake","6_oz_price_ounce","7_stevia_sugar_fructose","8_china_made china_made","9_chocolate_cocoa_hot choco...","10_peanut_butter_peanut but...","11_plant_seed_tree","12_popcorn_kernel_pop","13_date_expiration_expirati...","14_taste_bad_tasted","15_jerky_beef jerky_beef","16_cereal_oat_oatmeal","17_sauce_curry_hot sauce","18_candy_gift_basket","19_baby_son_month old","20_salt_sodium_salty","21_coconut water_coconut_wa...","22_trap_moth_fly","23_email_order_item","24_soup_miso_broth","25_leaking_leaked_seal","26_noodle_pasta_spaghetti","27_hair_shampoo_scalp","28_gum_xylitol_spry","29_olive_oil_truffle","30_dented_can_can dented","31_ginger_lemon_ginger flavor","32_bar_protein bar_granola ...","33_tuna_sardine_salmon","34_formula_arsenic_baby","35_cookie_cooky_ahoy","36_cracker_love cracker_box...","37_cheese_mac_mac cheese","38_chai_chai tea_clove","39_chip_kettle_kettle chip","40_chip_kale_kale chip","41_steam_steamer_beaba","42_msg_glutamate_monosodium","43_whatever_science diet_ea...","44_milk_soy milk_almond milk","45_chocolate_melted_ordered...","46_bacon_like bacon_bacon f...","47_licorice_black licorice_...","48_pretzel_burnt_burnt tast..."],"z":[[1.0000001,0.436997,0.73428875,0.507562,0.7331031,0.5900849,0.5234528,0.6405257,0.3971114,0.7415238,0.613991,0.47631326,0.5306277,0.55171037,0.72341835,0.58980495,0.62179166,0.6357831,0.5472088,0.53033483,0.53069717,0.6689458,0.2208439,0.40714324,0.5773149,0.5084533,0.50269735,0.37239808,0.55297476,0.6166019,0.4979433,0.64387,0.6187316,0.5732872,0.46521837,0.5829905,0.5545083,0.5652008,0.74349153,0.54584324,0.58260083,0.518091,0.5077007,0.40227616,0.67427486,0.58961457,0.55901384,0.60709614,0.5330413],[0.436997,1.0000002,0.4179501,0.7782678,0.48233718,0.5941765,0.48944744,0.4896906,0.7411395,0.5276502,0.5930599,0.49206448,0.4998939,0.5393186,0.5658762,0.6273239,0.5879419,0.5181136,0.5781701,0.67089736,0.48521718,0.3931804,0.5293515,0.39507967,0.54851323,0.48815036,0.6264816,0.41491 ...

# %% [markdown]
# **Some topics are semantically similar and may form higher-level clusters.**

# %%
topic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a749bfe9-b5b7-42b7-b15c-515a90c738ce" class="plotly-graph-div" style="height:935px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a749bfe9-b5b7-42b7-b15c-515a90c738ce")) {                    Plotly.newPlot(                        "a749bfe9-b5b7-42b7-b15c-515a90c738ce",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8370318956904751,0.8370318956904751,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.8370318956904751,0.8797139609771433,0.8797139609771433,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9807038434763045,0.9807038434763045,0.8797139609771433],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7405992983288283,0.7405992983288283,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.7405992983288283,0.746630787866526,0.746630787866526,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7718757724260175,0.7718757724260175,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.746630787866526,0.7899712620209397,0.7899712620209397,0.7718757724260175],"xaxis":"x","y":[-67.5,-67.5,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8119108235848611,0.8119108235848611,0.7899712620209397],"xaxis":"x","y":[-45.0,-45.0,-78.75,-78.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8119108235848611,0.8235326160553981,0.8235326160553981,0.0],"xaxis":"x","y":[-61.875,-61.875,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9807038434763045,1.0256074605190235,1.0256074605190235,0.8235326160553981],"xaxis":"x","y":[-16.25,-16.25,-83.4375,-83.4375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8234647292002194,0.8234647292002194,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.6778059789820248,0.6778059789820248,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.6778059789820248,0.7047001744521075,0.7047001744521075,0.0],"xaxis":"x","y":[-160.0,-160.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7493246991086242,0.7493246991086242,0.7047001744521075],"xaxis":"x","y":[-145.0,-145.0,-167.5,-167.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.7493246991086242,0.7659041420220102,0.7659041420220102,0.0],"xaxis":"x","y":[-156.25,-156.25,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.830937259277008,0.830937259277008,0.7659041420220102],"xaxis":"x","y":[-135.0,-135.0,-170.625,-170.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines" ...

# %% [markdown]
# ## Testing

# %%
test_review = "I bought this dog food hoping it would be a healthy choice, but it made my dog sick. He had stomach issues for days, and I had to visit the vet. I’ll never buy this brand again."
topic, prob = topic_model.transform(test_review)

print("Predicted Topic:", topic)
print("Probability:", prob)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-05-04 17:01:54,307 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-05-04 17:02:11,678 - BERTopic - Dimensionality - Completed ✓
# 2025-05-04 17:02:11,678 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-05-04 17:02:11,680 - BERTopic - Cluster - Completed ✓
# Predicted Topic: [1]
# Probability: [0.75502627]
# Top words in topic: [('dog', 0.31566474401445194), ('treat', 0.23684333169887137), ('dog food', 0.22357212442696656), ('toy', 0.22272746395441928), ('bone', 0.22162442277794261), ('chew', 0.203437756092578), ('puppy', 0.19997265407481432), ('food', 0.18585313116010832), ('pet', 0.18153067933563294), ('vet', 0.18059930313628544)]

# %%
test_review = "I had high hopes for this tea, but it was a complete disappointment. The flavor was incredibly weak and watery"
topic, prob = topic_model.transform(test_review)

print("Predicted Topic:", topic)
print("Probability:", prob)
print("Top words in topic:", topic_model.get_topic(topic[0]))
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-05-04 17:03:18,155 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-05-04 17:03:18,160 - BERTopic - Dimensionality - Completed ✓
# 2025-05-04 17:03:18,161 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-05-04 17:03:18,162 - BERTopic - Cluster - Completed ✓
# Predicted Topic: [2]
# Probability: [0.87007208]
# Top words in topic: [('tea', 0.4358793799580712), ('green tea', 0.3082123485256532), ('green', 0.2670820769048698), ('tea bag', 0.24752372355306748), ('leaf', 0.2352804505535101), ('jasmine', 0.21967011370646877), ('black tea', 0.19652412867467503), ('tea taste', 0.19140035078228346), ('matcha', 0.1827805383324629), ('earl', 0.18037728753099738)]

# %%
test_review = "I had high hopes for this tea, but it was a complete disappointment."
topic, prob = topic_model.transform(test_review)

print("Predicted Topic:", topic)
print("Probability:", prob)
print("Top words in topic:", topic_model.get_topic(topic[0]))
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-05-04 17:04:46,420 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-05-04 17:04:46,426 - BERTopic - Dimensionality - Completed ✓
# 2025-05-04 17:04:46,427 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-05-04 17:04:46,428 - BERTopic - Cluster - Completed ✓
# Predicted Topic: [2]
# Probability: [0.85255125]
# Top words in topic: [('tea', 0.4358793799580712), ('green tea', 0.3082123485256532), ('green', 0.2670820769048698), ('tea bag', 0.24752372355306748), ('leaf', 0.2352804505535101), ('jasmine', 0.21967011370646877), ('black tea', 0.19652412867467503), ('tea taste', 0.19140035078228346), ('matcha', 0.1827805383324629), ('earl', 0.18037728753099738)]

# %%
test_review = "I was really disappointed with this cocoa powder. It had a bitter, stale taste "
topic, prob = topic_model.transform(test_review)

print("Predicted Topic:", topic)
print("Probability:", prob)
print("Top words in topic:", topic_model.get_topic(topic[0]))
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-05-04 17:20:55,494 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-05-04 17:20:55,500 - BERTopic - Dimensionality - Completed ✓
# 2025-05-04 17:20:55,500 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-05-04 17:20:55,502 - BERTopic - Cluster - Completed ✓
# Predicted Topic: [9]
# Probability: [0.76716408]
# Top words in topic: [('chocolate', 0.45938661812080545), ('cocoa', 0.4063697197190554), ('hot chocolate', 0.37204309548071457), ('hot', 0.3207766485659092), ('dark chocolate', 0.3030653631398925), ('hershey', 0.2613760960234172), ('lindt', 0.2605582810249242), ('dark', 0.26022404336671806), ('hot cocoa', 0.25478990121963135), ('milk chocolate', 0.25445231057509526)]
